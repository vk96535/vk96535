# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
data=pd.read_excel("D:/Excel sheets/mavoix_ml_sample_dataset.xlsx")

# %%
## print the top5 records
data.head()

# %%
data.columns
# Out:
# Index(['Application_ID', 'Current City', 'Python (out of 3)',
#        'R Programming (out of 3)', 'Deep Learning (out of 3)',
#        'PHP (out of 3)', 'MySQL (out of 3)', 'HTML (out of 3)',
#        'CSS (out of 3)', 'JavaScript (out of 3)', 'ReactJS (out of 3)',
#        'AJAX (out of 3)', 'Bootstrap (out of 3)', 'MongoDB (out of 3)',
#        'Node.js (out of 3)', 'Other skills', 'Degree', 'Stream',
#        'Current Year Of Graduation', 'Performance_PG', 'Performance_UG',
#        'Performance_12', 'Performance_10'],
#       dtype='object')

# %%
## print shape of dataset with rows and columns
data.shape
# Out:
# (392, 23)

# %%
data.describe()
# Out:
#        Python (out of 3)  R Programming (out of 3)  Deep Learning (out of 3)  \
# count         392.000000                392.000000                392.000000
# mean            1.375000                  0.566327                  0.461735
# std             0.975237                  0.905052                  0.842336
# min             0.000000                  0.000000                  0.000000
# 25%             0.000000                  0.000000                  0.000000
# 50%             2.000000                  0.000000                  0.000000
# 75%             2.000000                  1.000000                  1.000000
# max             3.000000                  3.000000                  3.000000
#
#        PHP (out of 3)  MySQL (out of 3)  HTML (out of 3)  CSS (out of 3)  \
# count      392.000000        392.000000       392.000000      392.000000
# mean         0.612245          0.403061         1.346939        1.045918
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 23 columns):
# Application_ID                392 non-null object
# Current City                  392 non-null object
# Python (out of 3)             392 non-null int64
# R Programming (out of 3)      392 non-null int64
# Deep Learning (out of 3)      392 non-null int64
# PHP (out of 3)                392 non-null int64
# MySQL (out of 3)              392 non-null int64
# HTML (out of 3)               392 non-null int64
# CSS (out of 3)                392 non-null int64
# JavaScript (out of 3)         392 non-null int64
# ReactJS (out of 3)            392 non-null int64
# AJAX (out of 3)               392 non-null int64
# Bootstrap (out of 3)          392 non-null int64
# MongoDB (out of 3)            392 non-null int64
# Node.js (out of 3)            392 non-null int64
# Other skills                  378 non-null object
# Degree                        380 non-null object
# ...

# %%
#count of null values
df=data.isnull().sum()
df
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# ReactJS (out of 3)              0
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# Other skills                   14
# Degree                         12
# Stream                         18
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %%
## 1 -step make the list of features which has missing values
features_with_na=[features for features in data.columns if data[features].isnull().sum()>1]

## 2- step print the feature name and the percentage of missing values
for feature in features_with_na:
    print(feature, np.round(data[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# Other skills 0.0357  % missing values
# Degree 0.0306  % missing values
# Stream 0.0459  % missing values
# Performance_PG 0.7372  % missing values
# Performance_UG 0.1378  % missing values
# Performance_12 0.4158  % missing values
# Performance_10 0.4515  % missing values

# %%
for feature in data:
    print('The feature is {} and number of categories are {}'.format(feature,len(data[feature].unique())))
# Out:
# The feature is Application_ID and number of categories are 392
# The feature is Current City and number of categories are 63
# The feature is Python (out of 3) and number of categories are 4
# The feature is R Programming (out of 3) and number of categories are 4
# The feature is Deep Learning (out of 3) and number of categories are 4
# The feature is PHP (out of 3) and number of categories are 4
# The feature is MySQL (out of 3) and number of categories are 4
# The feature is HTML (out of 3) and number of categories are 4
# The feature is CSS (out of 3) and number of categories are 4
# The feature is JavaScript (out of 3) and number of categories are 4
# The feature is ReactJS (out of 3) and number of categories are 3
# The feature is AJAX (out of 3) and number of categories are 2
# The feature is Bootstrap (out of 3) and number of categories are 4
# The feature is MongoDB (out of 3) and number of categories are 3
# The feature is Node.js (out of 3) and number of categories are 3
# ...

# %%
for feature in data:
    print('The feature is {} and number of categories are {}'.format(feature,(data[feature].value_counts())))
# Out:
# The feature is Application_ID and number of categories are ML0178    1
# ML0341    1
# ML0176    1
# ML0207    1
# ML0261    1
#          ..
# ML0049    1
# ML0094    1
# ML0030    1
# ML0319    1
# ML0285    1
# Name: Application_ID, Length: 392, dtype: int64
# The feature is Current City and number of categories are Bangalore     214
# Hyderabad      22
# Banglore       14
# Chennai        12
# Pune           10
#              ...
# Tiruppur        1
# Chandigarh      1
# Mangaluru       1
# Kolhapur        1
# Ghaziabad       1
# Name: Current City, Length: 63, dtype: int64
# The feature is Python (out of 3) and number of categories are 2    182
# 0    105
# 1     70
# 3     35
# Name: Python (out of 3), dtype: int64
# The feature is R Programming (out of 3) and number of categories are 0    272
# 2     82
# 1     28
# 3     10
# Name: R Programming (out of 3), dtype: int64
# The feature is Deep Learning (out of 3) and number of categories are 0    292
# 2     63
# 1     28
# ...

# %%
#list of numerical variables
numerical_features=[feature for feature in data.columns if data[feature].dtypes !='O']

print('Number of numerical_features: ',len(numerical_features))

data[numerical_features].head()
# Out:
# Number of numerical_features:  14
#    Python (out of 3)  R Programming (out of 3)  Deep Learning (out of 3)  \
# 0                  0                         2                         0
# 1                  2                         0                         0
# 2                  3                         0                         1
# 3                  2                         0                         2
# 4                  2                         0                         0
#
#    PHP (out of 3)  MySQL (out of 3)  HTML (out of 3)  CSS (out of 3)  \
# 0               2                 0                2               3
# 1               2                 2                2               2
# 2               2                 2                2               0
# 3               1                 0                2               0
# 4               2                 0                2               1
#
#    JavaScript (out of 3)  ReactJS (out of 3)  AJAX (out of 3)  \
# ...

# %%
#list of categorical variables
categorical_features=[feature for feature in data.columns if data[feature].dtypes =='O']

print('Number of categorical_features: ',len(numerical_features))

data[categorical_features].head()
# Out:
# Number of categorical_features:  14
#   Application_ID Current City  \
# 0         ML0001    Bangalore
# 1         ML0002    Bangalore
# 2         ML0003    Bangalore
# 3         ML0004    Bangalore
# 4         ML0005    Bangalore
#
#                                         Other skills  \
# 0                                      R Programming
# 1  Data Science, Machine Learning, Neural Network...
# 2  Algorithms, Data Structures, Python, C Program...
# 3  CSS, Deep Learning, Embedded Systems, HTML, Ma...
# 4  HTML, OpenCV, Python, SQL, C++ Programming, CS...
#
#                             Degree                          Stream  \
# 0       Bachelor of Science (B.Sc)                     Mathematics
# 1  Bachelor of Technology (B.Tech)  Computer Science & Engineering
# 2         Master of Science (M.Sc)               Computer  Science
# 3    Bachelor of Engineering (B.E)   Electronics and Communication
# 4  Bachelor of Technology (B.Tech)          Production Engineering
#
# ...

# %%
data_science =[feature for feature in numerical_features if 'R Programming (out of 3)' in feature or 'Python (out of 3)' in feature or 'Deep Learning (out of 3)' in feature or 'MySQL (out of 3)' in feature]

data_science
# Out:
# ['Python (out of 3)',
#  'R Programming (out of 3)',
#  'Deep Learning (out of 3)',
#  'MySQL (out of 3)']

# %%
for feature in data_science:
    print(feature, data[feature].unique())
# Out:
# Python (out of 3) [0 2 3 1]
# R Programming (out of 3) [2 0 1 3]
# Deep Learning (out of 3) [0 1 2 3]
# MySQL (out of 3) [0 2 1 3]

# %%
for feature in data_science:
    print(feature, data[feature]>=2,flush=False)
# Out:
# Python (out of 3) 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 387     True
# 388     True
# 389    False
# 390     True
# 391     True
# Name: Python (out of 3), Length: 392, dtype: bool
# R Programming (out of 3) 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 387    False
# 388    False
# 389    False
# 390     True
# 391     True
# Name: R Programming (out of 3), Length: 392, dtype: bool
# Deep Learning (out of 3) 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# Name: Deep Learning (out of 3), Length: 392, dtype: bool
# MySQL (out of 3) 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# Name: MySQL (out of 3), Length: 392, dtype: bool

# %%
df=data[data['Python (out of 3)']==3]
df.head()

# %%
data[data['Python (out of 3)']>=2][(data['Deep Learning (out of 3)']>=2)][(data['MySQL (out of 3)']>=2)]
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#     Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 34          ML0035             4                  3                         3
# 93          ML0094            23                  3                         1
# 124         ML0125             4                  3                         2
# 139         ML0140             9                  2                         0
# 154         ML0155             5                  2                         0
# 178         ML0179            22                  2                         0
# 182         ML0183             4                  2                         2
# 214         ML0215             4                  2                         0
# 254         ML0255             4                  2                         3
# ...

# %%
data[data['Python (out of 3)']>=2][(data['Deep Learning (out of 3)']>=2)][(data['MySQL (out of 3)']>=2)]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data["Current Year Of Graduation"]=encoder.fit_transform(data['Current Year Of Graduation'])
data["Current City"]=encoder.fit_transform(data['Current City'])
#data["Stream"]=encoder.fit_transform(data['Stream'])
data
# Out:
#     Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0           ML0001             4                  0                         2
# 1           ML0002             4                  2                         0
# 2           ML0003             4                  3                         0
# 3           ML0004             4                  2                         0
# 4           ML0005             4                  2                         0
# ..             ...           ...                ...                       ...
# 387         ML0388            22                  2                         1
# 388         ML0389             4                  2                         0
# 389         ML0390            41                  1                         0
# 390         ML0391            29                  2                         2
# 391         ML0392            15                  2                         3
#
# ...
